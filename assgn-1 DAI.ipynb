# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

file_path = r"C:\Users\shiva\OneDrive\Desktop\C++\car_price_dataset.csv" 
data = pd.read_csv(file_path)

# Display the first few rows
data.head()
# Out:
#         Brand   Model  Year  Engine_Size Fuel_Type    Transmission  Mileage  \
# 0         Kia     Rio  2020          4.2    Diesel          Manual   289944
# 1   Chevrolet  Malibu  2012          2.0    Hybrid       Automatic     5356
# 2    Mercedes     GLA  2020          4.2    Diesel       Automatic   231440
# 3        Audi      Q5  2023          2.0  Electric          Manual   160971
# 4  Volkswagen    Golf  2003          2.6    Hybrid  Semi-Automatic   286618
#
#    Doors  Owner_Count  Price
# 0      3            5   8501
# 1      2            3  12092
# 2      4            2  11171
# 3      2            1  11780
# 4      3            3   2867

# %%
# Basic statistics of numerical columns
data.describe()
# Out:
#                Year   Engine_Size        Mileage         Doors   Owner_Count  \
# count  10000.000000  10000.000000   10000.000000  10000.000000  10000.000000
# mean    2011.543700      3.000560  149239.111800      3.497100      2.991100
# std        6.897699      1.149324   86322.348957      1.110097      1.422682
# min     2000.000000      1.000000      25.000000      2.000000      1.000000
# 25%     2006.000000      2.000000   74649.250000      3.000000      2.000000
# 50%     2012.000000      3.000000  149587.000000      3.000000      3.000000
# 75%     2017.000000      4.000000  223577.500000      4.000000      4.000000
# max     2023.000000      5.000000  299947.000000      5.000000      5.000000
#
#              Price
# count  10000.00000
# mean    8852.96440
# std     3112.59681
# min     2000.00000
# 25%     6646.00000
# 50%     8858.50000
# 75%    11086.50000
# max    18301.00000

# %%
sns.countplot(data['Brand']) # This will count the occurence of each brand --clearly ford cars are greater in count
# Out:
# <Axes: xlabel='count', ylabel='Brand'>

# %%
sns.countplot(data['Fuel_Type']) # we come to know that most of the cars are electric then diesel followed by petrol and hybrid
# Out:
# <Axes: xlabel='count', ylabel='Fuel_Type'>

# %%
sns.countplot(data['Transmission']) #manual cars are higher than automatic and semiautomatic
# Out:
# <Axes: xlabel='count', ylabel='Transmission'>

# %%
import matplotlib.pyplot as plt
data.hist(figsize=(12, 8), bins=30, edgecolor='black')
plt.show()

# %%
data['Brand'].value_counts().plot(kind="pie",autopct="%1.2ff%%")
# Out:
# <Axes: ylabel='count'>

# %%
data['Fuel_Type'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Fuel_Type'>

# %%
sns.distplot(data['Engine_Size'])
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_8044\3140190713.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Engine_Size'])
# <Axes: xlabel='Engine_Size', ylabel='Density'>

# %%
sns.distplot(data['Price'])
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_8044\4196895882.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
sns.barplot(x=data['Brand'],y=data['Engine_Size'])
# Out:
# <Axes: xlabel='Brand', ylabel='Engine_Size'>

# %%
sns.scatterplot(x=data['Engine_Size'],y=data['Price'])
# Out:
# <Axes: xlabel='Engine_Size', ylabel='Price'>

# %%
sns.scatterplot(x=data['Price'],y=data['Mileage'])
# Out:
# <Axes: xlabel='Price', ylabel='Mileage'>

# %%
sns.boxplot(x=data['Owner_Count'], y=data['Brand'],hue=data['Year'])
# Out:
# <Axes: xlabel='Owner_Count', ylabel='Brand'>

# %%
sns.boxplot(x=data['Fuel_Type'], y=data['Model'],hue=data['Brand'])
# Out:
# <Axes: xlabel='Fuel_Type', ylabel='Model'>

# %%
sns.boxplot(x=data['Model'],y=data['Engine_Size'],hue=data['Transmission'])
# Out:
# <Axes: xlabel='Model', ylabel='Engine_Size'>
